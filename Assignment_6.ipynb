# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv"
ds = pd.read_csv(url)
ds.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
ds.tail(10)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 356  10/22/2008  Canberra      3.4     15.0       0.8          4.8      11.7
# 357  10/23/2008  Canberra      3.2     18.0       0.0          7.4      12.2
# 358  10/24/2008  Canberra      0.9     20.7       0.0          5.4       8.4
# 359  10/25/2008  Canberra      3.3     25.5       0.0          5.2      10.8
# 360  10/26/2008  Canberra      7.9     26.1       0.0          6.8       3.5
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# ...

# %%
ds.shape
# Out:
# (366, 24)

# %%
#Univariate plot for minimum temperature
MinTemp=ds['MinTemp']
sns.distplot(MinTemp, kde=True, rug=True)
plt.show()
plt.close()
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#Univariate plot for Maximum temperature
MaxTemp=ds['MaxTemp']
sns.distplot(MaxTemp, kde=True, rug=True)
plt.show()
plt.close()
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#KDE plot comparison
for col in ['MinTemp', 'MaxTemp']:
    sns.kdeplot(ds[col], shade=True)
plt.show()
plt.close()
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#scatter plot with regression line
sns.lmplot(data = ds , x = 'MaxTemp' , y = 'MinTemp')
plt.show()
plt.close()

# %%
#KDE plot
sns.kdeplot(ds['Rainfall'], shade=True, bw=2, color='y' )
plt.show()
plt.close()
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#Jointplot Rainfall Vs. Evaporation
sns.jointplot(x='Rainfall', y='Evaporation', data=ds, size=12, ratio=15, space=0.5)
plt.show()
plt.close()

# %%
#scatterplot with histogram and r
sns.jointplot(data = ds , x = 'Sunshine' , y = 'Evaporation' , color = 'r')
plt.show()
plt.close()

# %%
#resid with r
sns.jointplot(data = ds , x = 'Temp9am' , y = 'Temp3pm' , color = 'black' , kind = 'resid')
plt.show()
plt.close()

# %%
#strip plot = categorical data vs. numerical data graph
sns.stripplot(data = ds , x = 'WindDir9am' , y = 'WindSpeed9am' , color = 'grey')
plt.show()
plt.close()

# %%
#strip plot= categorical data vs. numerical data graph
sns.stripplot(data = ds , x = 'WindDir3pm' , y = 'WindSpeed3pm' , color = 'orange')
plt.show()
plt.close()

# %%
#swarm plot = categorical data vs. numerical data graph without overlapping
sns.swarmplot(data = ds , x = 'Location' , y = 'Pressure9am' , color = 'grey')
plt.show()
plt.close()

# %%
#swarm plot 
sns.swarmplot(data = ds , x = 'RainToday' , y = 'Humidity3pm' , color = 'indigo')
plt.show()
plt.close()

# %%
#histogram and rug
sns.distplot(ds['Pressure3pm'] , hist = True , rug = True , kde = False)
plt.show()
plt.close()

# %%
#kde and rug
sns.distplot(ds['Pressure9am'] , hist = False , rug = True , kde = True , color = 'r')
plt.show()
plt.close()
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
#hex with r
sns.jointplot(data = ds , x = 'MaxTemp' , y = 'Humidity9am' , color = 'y' , kind = 'hex')
plt.show()
plt.close()

# %%
#Converting Wind Directions to appropiate radian angle values

from math import radians
from collections import Counter

dir={    'ENE': 22.5,
         'SSE': 292.5,
         'SE': 315,
         'E': 0,
         'S': 270,
         'N': 90,
         'WNW': 167.5,
         'ESE': 337.5,
         'NE': 45,
         'NNE': 77.5,
         'NNW': 112.5,
         'SW': 225,
         'W': 180,
         'WSW': 202.5,
         'SSW': 247.5,
         'NW': 135
    }

a=0
for x in ds['WindGustDir']:
    #print(x)
    if x in dir:
        print("direction =" + x)
        ds.ix[a,'WindGustDir'] = dir[x]
        a=a+1
        #print(x)
    else:
         x = None

ds['WindGustDir'].drop(ds.index[363:366])
ds=ds.convert_objects(convert_numeric=True)
ds.dtypes
# Out:
# C:\Users\naman\Anaconda3\lib\site-packages\ipykernel\__main__.py:36: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir      float64
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
#Plot showing wind gust speed to directions

ax = plt.subplot(111, polar=True)
ax.scatter(x=[radians(x) for x in ds['WindGustDir'].values], y=ds['WindGustSpeed'].values)
ax.set_theta_zero_location('E')
#(lines,labels) = thetagrids( range(0,360,18), ("XXXXX","YYYYY","ZZZZ","PPPP"))
ax.set_theta_direction(1)
plt.show()
